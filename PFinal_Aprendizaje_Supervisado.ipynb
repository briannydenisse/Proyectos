# %% [markdown]
# #Fase 1: Carga de datos y análisis descriptivo.

# %% [markdown]
# ##Importar el data set

# %%
#Importar dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b49f5407-a4c7-4805-b2aa-9596dfe0e987" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b49f5407-a4c7-4805-b2aa-9596dfe0e987">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
#Asignar datos al dataframe
import io
df_casoPractico= pd.read_csv(io.BytesIO(uploaded['ASI_casoPractico.csv']), sep = ';')

# %% [markdown]
# ## Analisis exploratorio

# %%
#Visualizar el data frame
df_casoPractico.head()
# Out:
#    ID    b     e  LBE  AC  FM  UC  ASTV  MSTV  ALTV  ...  Min  Max  Nmax  \
# 0   1  240   357  120   0   0   0    73   0.5    43  ...   62  126     2
# 1   2    5   632  132   4   0   4    17   2.1     0  ...   68  198     6
# 2   3  177   779  133   2   0   5    16   2.1     0  ...   68  198     5
# 3   4  411  1192  134   2   0   6    16   2.4     0  ...   53  170    11
# 4   5  533  1147  132   4   0   5    16   2.4     0  ...   53  170     9
#
#    Nzeros  Mode  Mean  Median  Variance  Tendency  Target
# 0       0   120   137     121        73         1       1
# 1       1   141   136     140        12         0       0
# 2       1   141   135     138        13         0       0
# 3       0   137   134     137        13         1       0
# 4       0   137   136     138        11         1       0
#
# [5 rows x 26 columns]

# %%
#Informacion de los datos
df_casoPractico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        2126 non-null   int64
#  1   b         2126 non-null   int64
#  2   e         2126 non-null   int64
#  3   LBE       2126 non-null   int64
#  4   AC        2126 non-null   int64
#  5   FM        2126 non-null   int64
#  6   UC        2126 non-null   int64
#  7   ASTV      2126 non-null   int64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   int64
#  10  MLTV      2126 non-null   float64
#  11  DL        2126 non-null   int64
#  12  DS        2126 non-null   int64
#  13  DP        2126 non-null   int64
#  14  DR        2126 non-null   int64
#  15  Width     2126 non-null   int64
#  16  Min       2126 non-null   int64
#  17  Max       2126 non-null   int64
#  18  Nmax      2126 non-null   int64
#  19  Nzeros    2126 non-null   int64
# ...

# %%
#Usando la funcion data type para ver la informacion del tipo de dato
df_casoPractico.dtypes
# Out:
# ID            int64
# b             int64
# e             int64
# LBE           int64
# AC            int64
# FM            int64
# UC            int64
# ASTV          int64
# MSTV        float64
# ALTV          int64
# MLTV        float64
# DL            int64
# DS            int64
# DP            int64
# DR            int64
# Width         int64
# Min           int64
# Max           int64
# Nmax          int64
# Nzeros        int64
# Mode          int64
# Mean          int64
# Median        int64
# Variance      int64
# Tendency      int64
# Target        int64
# dtype: object

# %% [markdown]
# **Clasifique cada variable según su tipo, cualitativa o cuantitativa discreta o continúa.**
#
#
# ID: Cuantitativa continua.
# B: Cuantitativa continua.
# E: Cuantitativa continua.
# LBE: Cuantitativa continua.
# AC: Cuantitativa continua.
# FM: Cuantitativa continua.
# UC: Cuantitativa continua.
# ASTV: Cuantitativa continua.
# MSTV: Cuantitativa continua.
# ALTV: Cuantitativa continua.
# MLTV: Cuantitativa continua.
# DL: Cuantitativa discreta.
# DS: Cuantitativa discreta.
# DP: Cuantitativa discreta.
# DR: Cuantitativa continua.
# WIDTH: Cuantitativa continua.
# MIN: Cuantitativa continua.
# MAX: Cuantitativa continua.
# NMAX: Cuantitativa discreta.
# NZEROS: Cualitativa discreta.
# MODE: Cuantitativa continua.
# MEAN: Cuantitativa continua.
# VARIANCE: Cuantitativa continua.
# TENDENCY: Cualitativa politomica.
# TARGET: Cualitativa dicotómica.

# %%
#Valores unicos
df_casoPractico.agg(['nunique'])
# Out:
#            ID    b     e  LBE  AC  FM  UC  ASTV  MSTV  ALTV  ...  Min  Max  \
# nunique  2126  979  1064   48  22  96  19    75    57    87  ...  109   86
#
#          Nmax  Nzeros  Mode  Mean  Median  Variance  Tendency  Target
# nunique    18       9    88   103      95       133         3       2
#
# [1 rows x 26 columns]

# %%
#Eliminar columnas no necesarias
data = df_casoPractico.drop(["ID","b","e","DR"], axis = 1)
data.head()
# Out:
#    LBE  AC  FM  UC  ASTV  MSTV  ALTV  MLTV  DL  DS  ...  Min  Max  Nmax  \
# 0  120   0   0   0    73   0.5    43   2.4   0   0  ...   62  126     2
# 1  132   4   0   4    17   2.1     0  10.4   2   0  ...   68  198     6
# 2  133   2   0   5    16   2.1     0  13.4   2   0  ...   68  198     5
# 3  134   2   0   6    16   2.4     0  23.0   2   0  ...   53  170    11
# 4  132   4   0   5    16   2.4     0  19.9   0   0  ...   53  170     9
#
#    Nzeros  Mode  Mean  Median  Variance  Tendency  Target
# 0       0   120   137     121        73         1       1
# 1       1   141   136     140        12         0       0
# 2       1   141   135     138        13         0       0
# 3       0   137   134     137        13         1       0
# 4       0   137   136     138        11         1       0
#
# [5 rows x 22 columns]

# %%
#Valores nulos
data.isnull().sum()
# Out:
# LBE         0
# AC          0
# FM          0
# UC          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# DL          0
# DS          0
# DP          0
# Width       0
# Min         0
# Max         0
# Nmax        0
# Nzeros      0
# Mode        0
# Mean        0
# Median      0
# Variance    0
# Tendency    0
# Target      0
# dtype: int64

# %%
# LIBRERIAS PARA HACER GRAFICOS
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as xp

# %%
import numpy as np

# %% [markdown]
# **¿Cuál es la proporción de estados fetales normales? ¿y anormales?**

# %%
# Calcular la proporción de estados fetales normales (0)
proporcion_normales = data['Target'].value_counts(normalize=True).get(0, 0)
print("Proporción de estados fetales normales: {:.2%}".format(proporcion_normales))

# Calcular la proporción de estados fetales anormales (1)
proporcion_anormales = data['Target'].value_counts(normalize=True).get(1, 0)
print("Proporción de estados fetales anormales: {:.2%}".format(proporcion_anormales))
# Out:
# Proporción de estados fetales normales: 77.85%
# Proporción de estados fetales anormales: 22.15%

# %%
a, b = data['Target'].value_counts()
plt.figure(figsize = (13,5))
plt.subplot(121)
plt.pie([a, b], labels=["Normal", "Anormal"], autopct="%1.0f%%")
print(data["Target"].value_counts())
# Out:
# 0    1655
# 1     471
# Name: Target, dtype: int64

# %% [markdown]
# **Obtenga las medidas de centralización, localización y dispersión para las variables:  FM, ALTV y Median.**

# %%
data[['FM', 'ALTV', 'Median']].describe().T
# Out:
#          count        mean        std   min    25%    50%    75%    max
# FM      2126.0    7.241298  37.125309   0.0    0.0    0.0    2.0  564.0
# ALTV    2126.0    9.846660  18.396880   0.0    0.0    0.0   11.0   91.0
# Median  2126.0  138.090310  14.466589  77.0  129.0  139.0  148.0  186.0

# %% [markdown]
# **Obtenga el histograma para las variables: LBE, DS y Min.**

# %%
#Histogramas
fig, ax = plt.subplots(1,1,figsize=(5,5))
plt.style.use("seaborn")
data['LBE'].hist(ax=ax);
# Out:
# <ipython-input-15-092bad5ae055>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
fig, ax = plt.subplots(1,1,figsize=(5,5))
plt.style.use("seaborn")
data['DS'].hist(ax=ax);
# Out:
# <ipython-input-16-a4003b8c06d0>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
fig, ax = plt.subplots(1,1,figsize=(5,5))
plt.style.use("seaborn")
data['Min'].hist(ax=ax);
# Out:
# <ipython-input-17-63bd30da8ede>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %% [markdown]
# **Obtenga un gráfico box-plot para las variables: AC, ASTV y Mean.**

# %%
# BOX PLOT
# Seleccionar las columnas de interés
subset_df = data[['AC', 'ASTV', 'Mean']]

# Crear el box plot
subset_df.boxplot()

# Añadir etiquetas y título
plt.xlabel('Valores')
plt.ylabel('Variables')
plt.title('Box Plot para AC, ASTV y Mean')

# Mostrar el box plot
plt.show()

# %% [markdown]
# # Fase 2.1 Naive Bayes: Muestreo. Conjunto de entrenamiento y test.

# %% [markdown]
# **Enumere las 3 variables explicativas que presentan mayor correlación con el target.**

# %%
# Calcular la matriz de correlación
correlation_matrix = data.corr()

# Obtener las correlaciones absolutas con la variable "target"
correlations_with_target = correlation_matrix['Target'].abs().sort_values(ascending=False)

# Filtrar las correlaciones significativas
significant_correlations = correlations_with_target[correlations_with_target > 0.35]

# Visualizar la matriz de correlación
plt.figure(figsize=(12, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlación')
plt.show()

# Imprimir las variables con mayor correlación absoluta con "target"
print("Variables con mayor correlacion con 'target':")
print(significant_correlations)
# Out:
# Variables con mayor correlacion con 'target':
# Target    1.000000
# ASTV      0.493391
# ALTV      0.489400
# AC        0.369470
# Name: Target, dtype: float64

# %%
#Relacion univariante
plt.figure(figsize = (9,6))
sns.boxplot(x = 'Target', y= 'UC', data = data, palette="Reds")
# Out:
# <ipython-input-20-25b1dde01c65>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Target', y= 'UC', data = data, palette="Reds")
# <Axes: xlabel='Target', ylabel='UC'>

# %%
#Relacion univariante
plt.figure(figsize = (9,6))
sns.boxplot(x = 'Target', y= 'ALTV', data = data, palette="Reds")
# Out:
# <ipython-input-21-ba4739f99a0e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Target', y= 'ALTV', data = data, palette="Reds")
# <Axes: xlabel='Target', ylabel='ALTV'>

# %%
#Relacion univariante
plt.figure(figsize = (9,6))
sns.boxplot(x = 'Target', y= 'MSTV', data = data, palette="Reds")
# Out:
# <ipython-input-22-62db11c7d561>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Target', y= 'MSTV', data = data, palette="Reds")
# <Axes: xlabel='Target', ylabel='MSTV'>

# %% [markdown]
# **Cree un conjunto de entrenamiento y otro de test a partir del conjunto inicial de datos donde el conjunto de entrenamiento contenga el 60% de las observaciones.**

# %%
#Muestreo
from sklearn.model_selection import train_test_split
X = data.loc[:, data.columns != "Target"]
y = data.loc[:, data.columns == "Target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40, random_state = 0)

# %% [markdown]
# #Fase 3: Ajuste del algoritmo de Naive Bayes.

# %% [markdown]
# **A partir del conjunto de entrenamiento ajuste un modelo a partir del algoritmo de Naive Bayes.**

# %%
#Ajuste del modelo
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

modelNB = gnb.fit(X_train, y_train.values.ravel())
y_pred_train = modelNB.predict_proba(X_train)
y_pred_test = modelNB.predict_proba(X_test)

# %% [markdown]
# **Obtenga la curva ROC y el área bajo la curva para los conjuntos de entrenamiento y test.**

# %%
#Importar librerias
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

# %%
#Curva ROC y AUC

#Training
fpr_train, tpr_train, _ = roc_curve(y_train, y_pred_train[:, 1])
roc_auc_train = auc(fpr_train, tpr_train)

#Test
fpr_test, tpr_test, _ = roc_curve(y_test, y_pred_test[:, 1])
roc_auc_test = auc(fpr_test, tpr_test)

# %%
#Grafica
plt.figure()
lw = 2

plt.plot(fpr_train,tpr_train,color="darkgreen",lw=lw,label="ROC curve (area = %0.2f)" % roc_auc_train,)
plt.plot(fpr_test,tpr_test,color="darkred",lw=lw,label="ROC curve (area = %0.2f)" % roc_auc_test,)

plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Fase 2.2 Support Vector Machine (SVM): Muestreo. Conjunto de entrenamiento y test.

# %% [markdown]
# **Conjunto de entrenamiento y test.**

# %%
#Matplotlib
plt.rcParams['image.cmap'] = "bwr"
plt.rcParams['savefig.bbox'] = "tight"
style.use('ggplot') or plt.style.use('ggplot')

#warnings
import warnings
warnings.filterwarnings('ignore')

# %%
vars = ["ASTV","Mean"]
X_muestreo = data[vars]
y_muestreo = data.loc[:, data.columns == "Target"]

X_train_muestreo, X_test_muestreo, y_train_muestreo, y_test_muestreo = train_test_split(X_muestreo, y_muestreo, test_size = 0.50, random_state = 0)

fig, ax = plt.subplots(figsize=(6,4))
plt.scatter(X_train_muestreo.ASTV, X_train_muestreo.Mean, c = y_train_muestreo.Target, s=30, cmap=plt.cm.Paired)
ax.set_title("Estado de salud fetal");

# %%
#configuracion de svc
modelo = SVC(C = 10, kernel = 'linear', random_state=123)
modelo.fit(X_train_muestreo, y_train_muestreo)
# Out:
# SVC(C=10, kernel='linear', random_state=123)

# %%
plt.scatter(X_train_muestreo.ASTV, X_train_muestreo.Mean, c = y_train_muestreo.Target, s=30, cmap=plt.cm.Paired)

# Funcion de decision
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# Grid para evaluar el modelo
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = modelo.decision_function(xy).reshape(XX.shape)

# Plano de decision
ax.contour(
    XX, YY, Z, colors="k", levels=[-1, 0, 1], alpha=0.5, linestyles=["--", "-", "--"]
)
# plot support vectors
plt.show()

# %% [markdown]
# **A partir del conjunto de entrenamiento y test creados en el segundo sprint, ajuste un modelo utilizando el algoritmo SVM dejando los valores por defecto.**

# %%
#Muestreo

X_train_svm, X_test_svm, y_train_svm, y_test_svm = train_test_split(X, y, test_size = 0.40, random_state = 0)

# %% [markdown]
# # Fase 4: Ajuste del algoritmo de Support Vector Machine.

# %%
#Librerias
from mlxtend.plotting import plot_decision_regions
from matplotlib import style

# Preprocesado y modelado
from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

# Configuración warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# SVM Lineal
svmLineal = svm.SVC(C = 1
                    ,kernel='linear'
                    ,probability = True)

# Ajuste del modelo
svmLineal.fit(X_train_svm, y_train_svm)

# VALIDACION CON EL CONJUNTO DE TEST
y_proba_train_svm = svmLineal.predict_proba(X_train_svm)
y_proba_test_svm = svmLineal.predict_proba(X_test_svm)

# %%
# Entrenamiento
fpr_train_svm, tpr_train_svm, _ = roc_curve(y_train_svm, y_proba_train_svm[:, 1])
roc_auc_train_svm = auc(fpr_train_svm, tpr_train_svm)
#
# Test
fpr_test_svm, tpr_test_svm, _ = roc_curve(y_test_svm, y_proba_test_svm[:, 1])
roc_auc_test_svm = auc(fpr_test_svm, tpr_test_svm)

# %% [markdown]
# # Fase 5: Validación del algoritmo escogido

# %% [markdown]
# **Obtenga la curva ROC y el área bajo la curva para los conjuntos de entrenamiento y test.**

# %%
# Curva ROC y AUC
plt.figure()
lw = 2

plt.plot(fpr_train_svm,tpr_train_svm,color="darkgreen",lw=lw,label="ROC curve (area = %0.2f)" % roc_auc_train_svm,)
plt.plot(fpr_test_svm,tpr_test_svm,color="darkred",lw=lw,label="ROC curve (area = %0.2f)" % roc_auc_test_svm,)

plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# **Compare en la misma gráfica, la curva ROC y el AUC para el conjunto de test clasificado con Naive Bayes y con SVM.**

# %%
# Curva ROC y AUC
plt.figure()
lw = 2

plt.plot(fpr_test,tpr_test,color="yellow",lw=lw,label="ROC curve Naive Bayes (area = %0.2f)" % roc_auc_test,)
plt.plot(fpr_test_svm,tpr_test_svm,color="green",lw=lw,label="ROC curve SVM (area = %0.2f)" % roc_auc_test_svm,)

plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC para el conjunto de test de ambos modelos")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# **Precisión del modelo**

# %%
#PREDICCIONES
predicciones_train = svmLineal.predict(X_train_svm)
predicciones_test = svmLineal.predict(X_test_svm)

# %%
accuracy = accuracy_score(y_true = y_train_svm,y_pred = predicciones_train,normalize = True)
print(f"El accuracy de training es: {100*accuracy}%")

accuracy = accuracy_score(y_true = y_test_svm,y_pred = predicciones_test,normalize = True)
print(f"El accuracy de test es: {100*accuracy}%")
# Out:
# El accuracy de training es: 92.23529411764706%
# El accuracy de test es: 89.77673325499413%

# %% [markdown]
# **Matriz de confusión**

# %%
confusion_matrix = pd.crosstab(
    y_test_svm.Target.ravel(),
    predicciones_test,
    rownames=['Real'],
    colnames=['Predicción']
)
print(confusion_matrix)
# Out:
# Predicción    0    1
# Real
# 0           625   31
# 1            56  139

# %% [markdown]
# # **Adicional:** Búsqueda de la mejor combinación de hiperparámetros en el algoritmo de SVM utilizando la función Grid Search de Scikit Learn.

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Hiperparametros
param_grid = [
    {"kernel": ["rbf"], "gamma": [1e-3, 1e-4], "C": [0.1,1,10]},
    {"kernel": ["linear"], "C": [0.1,1,10]},
    {"kernel": ["poly"], "C": [0.1,1,10], "degree": [2,3]},
]

grid = GridSearchCV(
        estimator  = SVC(),
        param_grid = param_grid,
        scoring    = 'roc_auc',
        n_jobs     = -1,
        cv         = 3,
        verbose    = 0,
        return_train_score = True
      )

grid.fit(X = X_train_svm, y = y_train_svm)
# Out:
# GridSearchCV(cv=3, estimator=SVC(), n_jobs=-1,
#              param_grid=[{'C': [0.1, 1, 10], 'gamma': [0.001, 0.0001],
#                           'kernel': ['rbf']},
#                          {'C': [0.1, 1, 10], 'kernel': ['linear']},
#                          {'C': [0.1, 1, 10], 'degree': [2, 3],
#                           'kernel': ['poly']}],
#              return_train_score=True, scoring='roc_auc')

# %%
# Resultados del grid

resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)')\
    .drop(columns = 'params')\
    .sort_values('mean_test_score', ascending = False) \
    .head(10)
# Out:
#    param_C param_gamma param_kernel param_degree  mean_test_score  \
# 7        1         NaN       linear          NaN         0.961140
# 5       10      0.0001          rbf          NaN         0.960422
# 6      0.1         NaN       linear          NaN         0.959171
# 8       10         NaN       linear          NaN         0.957626
# 3        1      0.0001          rbf          NaN         0.949020
# 4       10       0.001          rbf          NaN         0.947823
# 2        1       0.001          rbf          NaN         0.944961
# 14      10         NaN         poly            3         0.942557
# 13      10         NaN         poly            2         0.937084
# 1      0.1      0.0001          rbf          NaN         0.929805
#
#     std_test_score  mean_train_score  std_train_score
# 7         0.009888          0.971758         0.004486
# 5         0.005075          0.982315         0.001190
# 6         0.011102          0.968995         0.006302
# ...

# %%
# mejores parametros
print(grid.best_params_)

# como luce el modelo
print(grid.best_estimator_)
# Out:
# {'C': 1, 'kernel': 'linear'}
# SVC(C=1, kernel='linear')

# %% [markdown]
# # Tratamiento de Outliers

# %%
#Eliminacion de Outliers
Q1 = data['ALTV'].quantile(0.25)
Q3 = data['ALTV'].quantile(0.75)
IQR = Q3 - Q1
df_filtered = data[(data['ALTV'] >= Q1 - 1.5 * IQR) & (data['ALTV'] <= Q3 + 1.5 * IQR)]

# %%
#Imputación de Outliers con valores mas tipicos
Q1 = data['UC'].quantile(0.25)
Q3 = data['UC'].quantile(0.75)
IQR = Q3 - Q1


median_value = data['UC'].median()

df_filtered.loc[:, 'UC'] = np.where((df_filtered['UC'] < Q1 - 1.5 * IQR) | (df_filtered['UC'] > Q3 + 1.5 * IQR), median_value, df_filtered['UC'])

# %%
#Transformación de Variables
df_filtered['AC'] = np.log1p(df_filtered['AC'])

# %%
#Muestreo con nuevo df
from sklearn.model_selection import train_test_split
X_nuevo = df_filtered.loc[:, df_filtered.columns != "Target"]
y_nuevo = df_filtered.loc[:, df_filtered.columns == "Target"]

X_train_nuevo, X_test_nuevo, y_train_nuevo, y_test_nuevo = train_test_split(X_nuevo, y_nuevo, test_size = 0.40, random_state = 0)

# %%
#busqueda mejores parametros para nuevo df
# Hiperparametros
param_grid = [
    {"kernel": ["rbf"], "gamma": [1e-3, 1e-4], "C": [0.1,1,10]},
    {"kernel": ["linear"], "C": [0.1,1,10]},
    {"kernel": ["poly"], "C": [0.1,1,10], "degree": [2,3]},
]

grid = GridSearchCV(
        estimator  = SVC(),
        param_grid = param_grid,
        scoring    = 'roc_auc',
        n_jobs     = -1,
        cv         = 3,
        verbose    = 0,
        return_train_score = True
      )

grid.fit(X = X_train_nuevo, y = y_train_nuevo)
# Out:
# GridSearchCV(cv=3, estimator=SVC(), n_jobs=-1,
#              param_grid=[{'C': [0.1, 1, 10], 'gamma': [0.001, 0.0001],
#                           'kernel': ['rbf']},
#                          {'C': [0.1, 1, 10], 'kernel': ['linear']},
#                          {'C': [0.1, 1, 10], 'degree': [2, 3],
#                           'kernel': ['poly']}],
#              return_train_score=True, scoring='roc_auc')

# %%
# mejores parametros
print(grid.best_params_)

# como luce el modelo
print(grid.best_estimator_)
# Out:
# {'C': 1, 'kernel': 'linear'}
# SVC(C=1, kernel='linear')

# %%
# SVM Lineal
svmLineal = svm.SVC(C = 1
                    ,kernel='linear'
                    ,probability = True)

# Ajuste del modelo
svmLineal.fit(X_train_nuevo, y_train_nuevo)

# VALIDACION CON EL CONJUNTO DE TEST
y_proba_train_nuevo = svmLineal.predict_proba(X_train_nuevo)
y_proba_test_nuevo = svmLineal.predict_proba(X_test_nuevo)

# %%
# Entrenamiento
fpr_train_nuevo, tpr_train_nuevo, _ = roc_curve(y_train_nuevo, y_proba_train_nuevo[:, 1])
roc_auc_train_nuevo = auc(fpr_train_nuevo, tpr_train_nuevo)
#
# Test
fpr_test_nuevo, tpr_test_nuevo, _ = roc_curve(y_test_nuevo, y_proba_test_nuevo[:, 1])
roc_auc_test_nuevo = auc(fpr_test_nuevo, tpr_test_nuevo)

# %%
# Curva ROC y AUC
plt.figure()
lw = 2

plt.plot(fpr_train_nuevo,tpr_train_nuevo,color="blue",lw=lw,label="ROC curve (area = %0.2f)" % roc_auc_train_nuevo,)
plt.plot(fpr_test_nuevo,tpr_test_nuevo,color="green",lw=lw,label="ROC curve (area = %0.2f)" % roc_auc_test_nuevo,)

plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC")
plt.legend(loc="lower right")
plt.show()
