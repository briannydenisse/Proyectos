# %% [markdown]
# # **Proyecto Final - Brianny Hernández**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('incident.csv')

# %%
df.head()
# Out:
#    incident_id incident_type   incident_timestamp  location_x  location_y  \
# 0            1          Fire  2024-05-01 10:15:00      123.45       678.9
# 1            2     Collision  2024-05-02 14:20:00      223.45       778.9
# 2            3       Medical  2024-05-03 08:30:00      323.45       878.9
# 3            4          Fire  2024-05-04 11:45:00      423.45       978.9
# 4            5     Collision  2024-05-05 16:10:00      523.45      1078.9
#
#    location_z spaceship_id  crew_size emergency_level response_team_id  \
# 0      234.56       SS-001          5            High            RT-01
# 1      334.56       SS-002          8          Medium            RT-02
# 2      434.56       SS-003          3             Low            RT-03
# 3      534.56       SS-004          6            High            RT-04
# 4      634.56       SS-005          7          Medium            RT-05
#
#    response_time_minutes       status
# 0                     15     Resolved
# ...

# %%
#el número de incidentes por estado.

status_counts = df['status'].value_counts()

plt.figure(figsize=(10, 6))
status_counts.plot(kind='bar', color=['blue', 'orange'])
plt.title('Número de Incidentes por Estado')
plt.xlabel('Estado')
plt.ylabel('Número de Incidentes')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Contar el número de incidentes por tipo
incident_type_counts = df['incident_type'].value_counts()


plt.figure(figsize=(10, 6))
incident_type_counts.plot(kind='bar', color=['red', 'green', 'blue'])
plt.title('Número de Incidentes por Tipo')
plt.xlabel('Tipo de Incidente')
plt.ylabel('Número de Incidentes')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()

# %%
#el promedio de tiempo de respuesta de incidentes por tipo

average_response_time = df.groupby('incident_type')['response_time_minutes'].mean()

# Crear la gráfica
plt.figure(figsize=(10, 6))
average_response_time.plot(kind='bar', color=['red', 'green', 'blue'])
plt.title('Promedio de Tiempo de Respuesta por Tipo de Incidente')
plt.xlabel('Tipo de Incidente')
plt.ylabel('Promedio de Tiempo de Respuesta (minutos)')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()

# %%
#el número de incidentes por equipo de respuesta
response_team_counts = df['response_team_id'].value_counts()


plt.figure(figsize=(12, 6))
response_team_counts.plot(kind='bar', color='purple')
plt.title('Número de Incidentes por Equipo de Respuesta')
plt.xlabel('Equipo de Respuesta')
plt.ylabel('Número de Incidentes')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()

# %%
# El promedio de tiempo de respuesta por equipo de respuesta
average_response_time_by_team = df.groupby('response_team_id')['response_time_minutes'].mean()

plt.figure(figsize=(12, 6))
average_response_time_by_team.plot(kind='bar', color='cyan')
plt.title('Promedio de Tiempo de Respuesta por Equipo de Respuesta')
plt.xlabel('Equipo de Respuesta')
plt.ylabel('Promedio de Tiempo de Respuesta (minutos)')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()
